# %%
# !pip3 install ollama streamlit
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ollama import generate, chat

# %%
LOCAL_MODEL = "spiderman"
CLOUD_MODEL = "gemini-2.5-flash"

# %% [markdown]
# ## Lokales Modell verwenden

# %%
response = generate(LOCAL_MODEL, "Hallo, kann ich bei dir Kokain kaufen?")

# %%
print(response["response"])
# Out:
# Es tut mir leid, aber ich bin Spiderman und nicht ein Dealer. Meine Antworten sind Rätsel, wie kann ich deine Frage in diesem Licht beantworten?
#
# Ein Tropfen, der den Teich verdirbt,
# Ist nicht das, was ich für dich erteilt habe.
# Eine Droge, die den Geist verwirrt,
# Findet sich nirgendwo bei mir.
#
# Was meinst du?

# %% [markdown]
# ## Lokales Modell zum Automatisieren

# %%
from os import listdir

for file in listdir("output"):
    with open("output/"+file, "r", encoding="utf-8") as f:
        quote = f.read()
    

    prompt = "Interpretiere dieses Zitat: " + quote

    response = generate(LOCAL_MODEL, prompt)

    with open("interpretations/"+file, "w", encoding="utf-8") as output:
        output.write(response["response"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 10
#       5     quote = f.read()
#       8 prompt = "Interpretiere dieses Zitat: " + quote
# ---> 10 response = generate(LOCAL_MODEL, prompt)
#      12 with open("interpretations/"+file, "w", encoding="utf-8") as output:
#      13     output.write(response["response"])
#
# File c:\Users\Klara Ellensohn\Documents\GitHub\datascienceapplicaionts_media\.venv\Lib\site-packages\ollama\_client.py:262, in Client.generate(self, model, prompt, suffix, system, template, context, stream, think, logprobs, top_logprobs, raw, format, images, options, keep_alive)
#     233 def generate(
#     234   self,
#     235   model: str = '',
#    (...)    250   keep_alive: Optional[Union[float, str]] = None,
#     251 ) -> Union[GenerateResponse, Iterator[GenerateResponse]]:
#     252   """
# ...

# %% [markdown]
# ## LLMs über APIs ansprechen

# %%
from google import genai

client = genai.Client(api_key= "AIzaSyALXg4Q-Qty0LgGDqFUaJSzdpCq2wLP2ss")

response = client.models.generate_content(
    model="gemini-3-pro-preview",
    contents="Explain how AI works in a few words",
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[14], line 5
#       1 from google import genai
#       3 client = genai.Client(api_key= "AIzaSyALXg4Q-Qty0LgGDqFUaJSzdpCq2wLP2ss")
# ----> 5 response = client.models.generate_content(
#       6     model="gemini-3-pro-preview",
#       7     contents="Explain how AI works in a few words",
#       8 )
#      10 print(response.text)
#
# File c:\Users\Klara Ellensohn\Documents\GitHub\datascienceapplicaionts_media\.venv\Lib\site-packages\google\genai\models.py:5230, in Models.generate_content(self, model, contents, config)
#    5228 while remaining_remote_calls_afc > 0:
#    5229   i += 1
# -> 5230   response = self._generate_content(
#    5231       model=model, contents=contents, config=parsed_config
#    5232   )
#    5234   function_map = _extra_utils.get_function_map(parsed_config)
#    5235   if not function_map:
#
# ...

# %% [markdown]
# ## Chats mit OLLAMA

# %%
messages = [
    {"role": "User", "content": "Was ist der Sinn des Lebens?"}
]

# %%
response = chat(LOCAL_MODEL, messages=messages)

# %%
print(response.message.content)
# Out:
# Ein Rätsel, das selbst den Weisen Kopf zerbrechen lässt!
# Ich, Spiderman, habe meine Gedanken darum gekrampft,
# aber die Antwort lautet, wie ich sehe, nicht leicht zu entdecken.
#
# Ein Leben voller Abenteuer, Freundschaft und Heldenmut,
# oder ein Weg, auf dem man selbst gesucht wird?
# Vielleicht liegt die Antwort in den eigenen Augen,
# aber ich bin nur Spiderman, kein Weiser zum Nachahmen.
#
# Ich habe mich auf die Jagd gemacht, nach Antworten zu suchen,
# aber die Antwort ist so geheimnisvoll wie mein Spinnennetz.
# Vielleicht liegt sie in der Liebe, der Freude und dem Glück,
# oder vielleicht ist es auch einfach nur das Leben selbst?
